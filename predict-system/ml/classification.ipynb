# %% [markdown]
# # Overview
# ### 1. Requirements Analysis
# ### 2. EDA;Exploratory Data Analysis
# ### 3. Modeling
# ### 4. Hyperparameters Tuning
# ### 5. Model Save

# %% [markdown]
# ## 1. Requirements Analysis

# %% [markdown]
# ## 2. EDA

# %%
# impory library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# set display options
pd.set_option('display.max_rows', 1000)  
pd.set_option('display.max_columns', 1000)

# %%
# Data load
train_df = pd.read_csv('./dataset/ai_smatii_outlier_train.csv', index_col=0)
test_df = pd.read_csv('./dataset/ai_smatii_outlier_test.csv', index_col=0)

train_df.head()
# Out:
#    xacc_RAW_IMU  nav_pitch_NAV_CONTROLLER_OUTPUT  xgyro_RAW_IMU  \
# 0      0.257996                         0.531179       0.433329
# 1      0.258922                         0.526175       0.428617
# 2      0.258922                         0.535333       0.419349
# 3      0.258423                         0.545212       0.412595
# 4      0.257925                         0.539921       0.416050
#
#    zgyro_RAW_IMU  vy_GLOBAL_POSITION_INT  yacc_RAW_IMU  \
# 0       0.520224                0.472851      0.243184
# 1       0.519374                0.480183      0.247555
# 2       0.519439                0.499561      0.246681
# 3       0.520224                0.500609      0.242310
# 4       0.519766                0.502704      0.242018
#
#    chan14_raw_RC_CHANNELS  chan12_raw_RC_CHANNELS  vibration_x_VIBRATION  \
# 0                0.814169                0.744766               0.011300
# 1                0.814169                0.744766               0.011206
# 2                0.814169                0.744766               0.013552
# 3                0.814169                0.744766               0.008066
# 4                0.814169                0.744766               0.008227
#
#    accel_cal_z_SENSOR_OFFSETS  vx_LOCAL_POSITION_NED  zacc_RAW_IMU  \
# 0                    0.291499               0.423668      0.504735
# 1                    0.291499               0.428878      0.507830
# 2                    0.291499               0.437742      0.505463
# 3                    0.291499               0.436369      0.501823
# 4                    0.291499               0.433227      0.506191
#
#    groundspeed_VFR_HUD  servo8_raw_SERVO_OUTPUT_RAW  pitch_ATTITUDE  \
# 0             0.053529                          0.0        0.382567
# 1             0.040223                          0.0        0.375482
# 2             0.011039                          0.0        0.383907
# 3             0.010793                          0.0        0.387915
# 4             0.011109                          0.0        0.383268
#
#    ygyro_RAW_IMU  yaw_ATTITUDE  Vservo_POWER_STATUS  \
# 0       0.451477      0.434830              0.00000
# 1       0.449940      0.434366              0.00000
# 2       0.448979      0.433274              0.00000
# 3       0.454038      0.436290              0.00037
# 4       0.453718      0.435992              0.00000
#
#    servo3_raw_SERVO_OUTPUT_RAW  x_LOCAL_POSITION_NED  chan13_raw_RC_CHANNELS  \
# 0                     0.388889              0.481463                0.736323
# 1                     0.389918              0.481321                0.736323
# 2                     0.380658              0.481297                0.736323
# 3                     0.413580              0.481312                0.736323
# 4                     0.401235              0.481330                0.736323
#
#    voltages1_BATTERY_STATUS  mag_ofs_x_SENSOR_OFFSETS  chan16_raw_RC_CHANNELS  \
# 0                  0.738582                  0.375358                0.735961
# 1                  0.736522                  0.375358                0.735961
# 2                  0.736431                  0.375358                0.735961
# 3                  0.732815                  0.375358                0.735961
# 4                  0.735683                  0.375358                0.735961
#
#    airspeed_VFR_HUD  chancount_RC_CHANNELS  xmag_RAW_IMU  \
# 0          0.041263                    1.0      0.635232
# 1          0.041975                    1.0      0.637147
# 2          0.015536                    1.0      0.634993
# 3          0.013897                    1.0      0.634514
# 4          0.005202                    1.0      0.635232
#
#    nav_bearing_NAV_CONTROLLER_OUTPUT  accel_cal_x_SENSOR_OFFSETS  \
# 0                           0.436111                    0.350693
# 1                           0.436111                    0.350693
# 2                           0.436111                    0.350693
# 3                           0.436111                    0.350693
# 4                           0.436111                    0.350693
#
#    roll_ATTITUDE  zmag_RAW_IMU  vibration_y_VIBRATION  \
# 0       0.510928      0.451460               0.013286
# 1       0.524941      0.449713               0.019232
# 2       0.515603      0.451335               0.031248
# 3       0.515110      0.451460               0.014328
# 4       0.521087      0.450087               0.013717
#
#    mag_ofs_y_SENSOR_OFFSETS  vibration_z_VIBRATION  vy_LOCAL_POSITION_NED  \
# 0                   0.36859               0.013622               0.472215
# 1                   0.36859               0.016669               0.480322
# 2                   0.36859               0.028947               0.498508
# 3                   0.36859               0.015486               0.499901
# 4                   0.36859               0.012253               0.502453
#
#    vx_GLOBAL_POSITION_INT  press_abs_SCALED_PRESSURE  \
# 0                0.423618                   0.978635
# 1                0.429365                   0.978551
# 2                0.437764                   0.978533
# 3                0.436437                   0.978467
# 4                0.433343                   0.978398
#
#    accel_cal_y_SENSOR_OFFSETS  ymag_RAW_IMU  chan15_raw_RC_CHANNELS loginfo
# 0                    0.910376      0.848711                0.744766  normal
# 1                    0.910376      0.861262                0.744766  normal
# 2                    0.910376      0.855834                0.744766  normal
# 3                    0.910376      0.854817                0.744766  normal
# 4                    0.910376      0.858887                0.744766  normal

# %%
# dataframe의 feature data 유사 변수명 기준 정렬
train_df = train_df[['xacc_RAW_IMU','zacc_RAW_IMU','yacc_RAW_IMU',
'xgyro_RAW_IMU','ygyro_RAW_IMU','zgyro_RAW_IMU',
'xmag_RAW_IMU','ymag_RAW_IMU','zmag_RAW_IMU',
'vibration_x_VIBRATION','vibration_y_VIBRATION','vibration_z_VIBRATION',
'accel_cal_y_SENSOR_OFFSETS','accel_cal_x_SENSOR_OFFSETS','accel_cal_z_SENSOR_OFFSETS',
'chan12_raw_RC_CHANNELS','chan13_raw_RC_CHANNELS','chan14_raw_RC_CHANNELS',
'chan15_raw_RC_CHANNELS','chan16_raw_RC_CHANNELS','chancount_RC_CHANNELS',
'roll_ATTITUDE','pitch_ATTITUDE','yaw_ATTITUDE',
'x_LOCAL_POSITION_NED','vx_LOCAL_POSITION_NED','vy_LOCAL_POSITION_NED',
'vx_GLOBAL_POSITION_INT','vy_GLOBAL_POSITION_INT',
'mag_ofs_x_SENSOR_OFFSETS','mag_ofs_y_SENSOR_OFFSETS',
'servo3_raw_SERVO_OUTPUT_RAW','servo8_raw_SERVO_OUTPUT_RAW',
'airspeed_VFR_HUD','groundspeed_VFR_HUD',
'Vservo_POWER_STATUS','voltages1_BATTERY_STATUS',
'nav_bearing_NAV_CONTROLLER_OUTPUT','nav_pitch_NAV_CONTROLLER_OUTPUT',
'press_abs_SCALED_PRESSURE', 'loginfo']]

test_df = test_df[['xacc_RAW_IMU','zacc_RAW_IMU','yacc_RAW_IMU',
'xgyro_RAW_IMU','ygyro_RAW_IMU','zgyro_RAW_IMU',
'xmag_RAW_IMU','ymag_RAW_IMU','zmag_RAW_IMU',
'vibration_x_VIBRATION','vibration_y_VIBRATION','vibration_z_VIBRATION',
'accel_cal_y_SENSOR_OFFSETS','accel_cal_x_SENSOR_OFFSETS','accel_cal_z_SENSOR_OFFSETS',
'chan12_raw_RC_CHANNELS','chan13_raw_RC_CHANNELS','chan14_raw_RC_CHANNELS',
'chan15_raw_RC_CHANNELS','chan16_raw_RC_CHANNELS','chancount_RC_CHANNELS',
'roll_ATTITUDE','pitch_ATTITUDE','yaw_ATTITUDE',
'x_LOCAL_POSITION_NED','vx_LOCAL_POSITION_NED','vy_LOCAL_POSITION_NED',
'vx_GLOBAL_POSITION_INT','vy_GLOBAL_POSITION_INT',
'mag_ofs_x_SENSOR_OFFSETS','mag_ofs_y_SENSOR_OFFSETS',
'servo3_raw_SERVO_OUTPUT_RAW','servo8_raw_SERVO_OUTPUT_RAW',
'airspeed_VFR_HUD','groundspeed_VFR_HUD',
'Vservo_POWER_STATUS','voltages1_BATTERY_STATUS',
'nav_bearing_NAV_CONTROLLER_OUTPUT','nav_pitch_NAV_CONTROLLER_OUTPUT',
'press_abs_SCALED_PRESSURE', 'loginfo']]

# %%
print(train_df.shape, test_df.shape)    # train(1173933, 41) test(293484, 41)
# Out:
# (1173933, 41) (293484, 41)

# %%
# Missing vlaue check : 0
train_df.info() # all of feature data is numerical data
                # numerical data need to scaleing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1173933 entries, 0 to 395928
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   xacc_RAW_IMU                       1173933 non-null  float64
#  1   zacc_RAW_IMU                       1173933 non-null  float64
#  2   yacc_RAW_IMU                       1173933 non-null  float64
#  3   xgyro_RAW_IMU                      1173933 non-null  float64
#  4   ygyro_RAW_IMU                      1173933 non-null  float64
#  5   zgyro_RAW_IMU                      1173933 non-null  float64
#  6   xmag_RAW_IMU                       1173933 non-null  float64
#  7   ymag_RAW_IMU                       1173933 non-null  float64
#  8   zmag_RAW_IMU                       1173933 non-null  float64
#  9   vibration_x_VIBRATION              1173933 non-null  float64
#  10  vibration_y_VIBRATION              1173933 non-null  float64
#  11  vibration_z_VIBRATION              1173933 non-null  float64
#  12  accel_cal_y_SENSOR_OFFSETS         1173933 non-null  float64
#  13  accel_cal_x_SENSOR_OFFSETS         1173933 non-null  float64
#  14  accel_cal_z_SENSOR_OFFSETS         1173933 non-null  float64
#  15  chan12_raw_RC_CHANNELS             1173933 non-null  float64
#  16  chan13_raw_RC_CHANNELS             1173933 non-null  float64
#  17  chan14_raw_RC_CHANNELS             1173933 non-null  float64
#  18  chan15_raw_RC_CHANNELS             1173933 non-null  float64
#  19  chan16_raw_RC_CHANNELS             1173933 non-null  float64
#  20  chancount_RC_CHANNELS              1173933 non-null  float64
#  21  roll_ATTITUDE                      1173933 non-null  float64
#  22  pitch_ATTITUDE                     1173933 non-null  float64
#  23  yaw_ATTITUDE                       1173933 non-null  float64
#  24  x_LOCAL_POSITION_NED               1173933 non-null  float64
#  25  vx_LOCAL_POSITION_NED              1173933 non-null  float64
#  26  vy_LOCAL_POSITION_NED              1173933 non-null  float64
#  27  vx_GLOBAL_POSITION_INT             1173933 non-null  float64
#  28  vy_GLOBAL_POSITION_INT             1173933 non-null  float64
#  29  mag_ofs_x_SENSOR_OFFSETS           1173933 non-null  float64
#  30  mag_ofs_y_SENSOR_OFFSETS           1173933 non-null  float64
#  31  servo3_raw_SERVO_OUTPUT_RAW        1173933 non-null  float64
#  32  servo8_raw_SERVO_OUTPUT_RAW        1173933 non-null  float64
#  33  airspeed_VFR_HUD                   1173933 non-null  float64
#  34  groundspeed_VFR_HUD                1173933 non-null  float64
#  35  Vservo_POWER_STATUS                1173933 non-null  float64
#  36  voltages1_BATTERY_STATUS           1173933 non-null  float64
#  37  nav_bearing_NAV_CONTROLLER_OUTPUT  1173933 non-null  float64
#  38  nav_pitch_NAV_CONTROLLER_OUTPUT    1173933 non-null  float64
#  39  press_abs_SCALED_PRESSURE          1173933 non-null  float64
#  40  loginfo                            1173933 non-null  object
# dtypes: float64(40), object(1)
# memory usage: 376.2+ MB

# %%
# label data encording : we use label encoder becuase it has only two class
from sklearn.preprocessing import LabelEncoder
train_df['loginfo'] = LabelEncoder().fit_transform(train_df['loginfo']) # normal:1 / fail:0
test_df['loginfo'] = LabelEncoder().fit_transform(test_df['loginfo']) # normal:1 / fail:0

# %%
train_df.describe()
# Out:
#        xacc_RAW_IMU  zacc_RAW_IMU  yacc_RAW_IMU  xgyro_RAW_IMU  ygyro_RAW_IMU  \
# count  1.173933e+06  1.173933e+06  1.173933e+06   1.173933e+06   1.173933e+06
# mean   2.634723e-01  5.547921e-01  2.731790e-01   4.195418e-01   4.534686e-01
# std    1.557399e-02  1.044137e-01  6.189479e-02   1.049405e-02   7.080269e-03
# min   -8.720791e-02 -1.330406e-01 -1.527753e+00  -3.715490e-01  -4.149587e-02
# 25%    2.549338e-01  5.065714e-01  2.421904e-01   4.175604e-01   4.518057e-01
# 50%    2.583839e-01  5.103000e-01  2.499937e-01   4.192876e-01   4.534127e-01
# 75%    2.622634e-01  5.178040e-01  2.666280e-01   4.218575e-01   4.552922e-01
# max    6.229255e-01  2.215112e+00  1.822112e+00   1.272851e+00   1.310635e+00
#
#        zgyro_RAW_IMU  xmag_RAW_IMU  ymag_RAW_IMU  zmag_RAW_IMU  \
# count   1.173933e+06  1.173933e+06  1.173933e+06  1.173933e+06
# mean    5.200028e-01  5.619067e-01  8.355901e-01  4.325582e-01
# std     7.508271e-03  5.488857e-02  5.479530e-02  4.164295e-02
# min    -2.494970e-01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     5.191125e-01  5.083772e-01  7.947761e-01  4.445970e-01
# 50%     5.197692e-01  5.457157e-01  8.537992e-01  4.503369e-01
# 75%     5.207113e-01  6.223073e-01  8.636364e-01  4.530821e-01
# max     1.059369e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#        vibration_x_VIBRATION  vibration_y_VIBRATION  vibration_z_VIBRATION  \
# count           1.173933e+06           1.173933e+06           1.173933e+06
# mean            6.411188e-02           1.149461e-01           6.618194e-02
# std             6.127382e-02           1.181696e-01           7.146487e-02
# min             0.000000e+00           0.000000e+00           0.000000e+00
# 25%             1.015138e-02           2.010139e-02           2.815156e-02
# 50%             5.104208e-02           9.116517e-02           5.146349e-02
# 75%             1.075157e-01           1.805463e-01           7.926910e-02
# max             1.275319e+00           3.053944e+00           1.437874e+00
#
#        accel_cal_y_SENSOR_OFFSETS  accel_cal_x_SENSOR_OFFSETS  \
# count                1.173933e+06                1.173933e+06
# mean                 5.939645e-01                5.510706e-01
# std                  7.579220e-02                6.265628e-02
# min                  0.000000e+00                0.000000e+00
# 25%                  5.681510e-01                5.536453e-01
# 50%                  5.681510e-01                5.536453e-01
# 75%                  5.681510e-01                5.536453e-01
# max                  1.000000e+00                1.000000e+00
#
#        accel_cal_z_SENSOR_OFFSETS  chan12_raw_RC_CHANNELS  \
# count                1.173933e+06            1.173933e+06
# mean                 4.170027e-01            7.210990e-01
# std                  3.930641e-02            8.892878e-02
# min                  0.000000e+00            0.000000e+00
# 25%                  4.212504e-01            7.447657e-01
# 50%                  4.212504e-01            7.447657e-01
# 75%                  4.212504e-01            7.477567e-01
# max                  1.000000e+00            1.112662e+00
#
#        chan13_raw_RC_CHANNELS  chan14_raw_RC_CHANNELS  chan15_raw_RC_CHANNELS  \
# count            1.173933e+06            1.173933e+06            1.173933e+06
# mean             4.883297e-01            5.444267e-01            9.570726e-02
# std              3.361677e-01            3.722809e-01            2.495076e-01
# min              0.000000e+00            0.000000e+00            0.000000e+00
# 25%              0.000000e+00            0.000000e+00            0.000000e+00
# 50%              7.363233e-01            8.141689e-01            0.000000e+00
# 75%              7.363233e-01            8.141689e-01            0.000000e+00
# max              1.030557e+00            1.032153e+00            1.000000e+00
#
#        chan16_raw_RC_CHANNELS  chancount_RC_CHANNELS  roll_ATTITUDE  \
# count            1.173933e+06           1.173933e+06   1.173933e+06
# mean             9.502661e-02           1.287220e-01   4.517169e-01
# std              2.472529e-01           3.348921e-01   1.490780e-01
# min              0.000000e+00           0.000000e+00  -3.107291e-03
# 25%              0.000000e+00           0.000000e+00   5.066138e-01
# 50%              0.000000e+00           0.000000e+00   5.151344e-01
# 75%              0.000000e+00           0.000000e+00   5.192457e-01
# max              1.000000e+00           1.000000e+00   1.044450e+00
#
#        pitch_ATTITUDE  yaw_ATTITUDE  x_LOCAL_POSITION_NED  \
# count    1.173933e+06  1.173933e+06          1.173933e+06
# mean     4.142268e-01  6.094788e-01          4.515024e-01
# std      9.795717e-02  2.650688e-01          9.483984e-02
# min     -2.658797e-01 -8.282860e-06         -1.399987e-01
# 25%      3.626233e-01  4.079148e-01          4.683487e-01
# 50%      3.815698e-01  6.759442e-01          4.815090e-01
# 75%      4.019276e-01  8.842734e-01          4.836326e-01
# max      9.268880e-01  1.000000e+00          1.000000e+00
#
#        vx_LOCAL_POSITION_NED  vy_LOCAL_POSITION_NED  vx_GLOBAL_POSITION_INT  \
# count           1.173933e+06           1.173933e+06            1.173933e+06
# mean            4.382511e-01           5.070944e-01            4.382445e-01
# std             1.071861e-01           1.071214e-01            1.071650e-01
# min            -3.990165e-01          -6.561837e-01           -3.990165e-01
# 25%             4.338119e-01           5.013872e-01            4.338205e-01
# 50%             4.387154e-01           5.066913e-01            4.387154e-01
# 75%             4.431642e-01           5.117010e-01            4.431058e-01
# max             1.007048e+00           1.304921e+00            1.007048e+00
#
#        vy_GLOBAL_POSITION_INT  mag_ofs_x_SENSOR_OFFSETS  \
# count            1.173933e+06              1.173933e+06
# mean             5.070999e-01              3.881984e-01
# std              1.071028e-01              1.642243e-01
# min             -6.561837e-01             -6.361032e-01
# 25%              5.014340e-01              2.865330e-01
# 50%              5.067426e-01              3.782235e-01
# 75%              5.116413e-01              4.441261e-01
# max              1.304921e+00              1.000000e+00
#
#        mag_ofs_y_SENSOR_OFFSETS  servo3_raw_SERVO_OUTPUT_RAW  \
# count              1.173933e+06                 1.173933e+06
# mean               5.036723e-01                 4.885102e-01
# std                2.136582e-01                 1.772668e-01
# min               -7.467949e-01                 0.000000e+00
# 25%                3.621795e-01                 4.403292e-01
# 50%                3.846154e-01                 5.411523e-01
# 75%                7.211538e-01                 6.069959e-01
# max                1.000000e+00                 9.218107e-01
#
#        servo8_raw_SERVO_OUTPUT_RAW  airspeed_VFR_HUD  groundspeed_VFR_HUD  \
# count                 1.173933e+06      1.173933e+06         1.173933e+06
# mean                  1.023201e-01      1.228513e-01         1.377248e-01
# std                   2.558853e-01      1.800339e-01         1.783227e-01
# min                   0.000000e+00      0.000000e+00         0.000000e+00
# 25%                   0.000000e+00      0.000000e+00         4.287802e-03
# 50%                   0.000000e+00      6.271380e-03         1.175884e-02
# 75%                   0.000000e+00      2.970354e-01         3.035205e-01
# max                   1.000000e+00      8.985177e-01         1.318446e+00
#
#        Vservo_POWER_STATUS  voltages1_BATTERY_STATUS  \
# count         1.173933e+06              1.173933e+06
# mean          1.276371e-01              3.654184e-01
# std           3.218050e-01              1.581093e-01
# min           0.000000e+00              0.000000e+00
# 25%           0.000000e+00              3.408833e-01
# 50%           7.406036e-04              3.545740e-01
# 75%           7.591187e-03              3.601146e-01
# max           9.987039e-01              1.000000e+00
#
#        nav_bearing_NAV_CONTROLLER_OUTPUT  nav_pitch_NAV_CONTROLLER_OUTPUT  \
# count                       1.173933e+06                     1.173933e+06
# mean                        6.170910e-01                     5.226483e-01
# std                         2.671767e-01                     5.166108e-02
# min                         0.000000e+00                    -6.365127e-01
# 25%                         4.091944e-01                     4.972670e-01
# 50%                         6.941111e-01                     5.334791e-01
# 75%                         8.833333e-01                     5.418086e-01
# max                         1.000000e+00                     1.152774e+00
#
#        press_abs_SCALED_PRESSURE       loginfo
# count               1.173933e+06  1.173933e+06
# mean                9.589448e-01  6.627329e-01
# std                 5.051135e-02  4.727771e-01
# min                 0.000000e+00  0.000000e+00
# 25%                 9.425381e-01  0.000000e+00
# 50%                 9.683564e-01  1.000000e+00
# 75%                 9.833626e-01  1.000000e+00
# max                 9.989819e-01  1.000000e+00

# %%
# Correlation analysis
train_df.corr()
# Out:
#                                    xacc_RAW_IMU  zacc_RAW_IMU  yacc_RAW_IMU  \
# xacc_RAW_IMU                           1.000000      0.940895      0.854953
# zacc_RAW_IMU                           0.940895      1.000000      0.925334
# yacc_RAW_IMU                           0.854953      0.925334      1.000000
# xgyro_RAW_IMU                         -0.017787     -0.004600     -0.018874
# ygyro_RAW_IMU                         -0.002280     -0.009728      0.003055
# zgyro_RAW_IMU                         -0.015328     -0.015861     -0.011300
# xmag_RAW_IMU                          -0.128186     -0.113225     -0.083434
# ymag_RAW_IMU                           0.143916      0.140010      0.070075
# zmag_RAW_IMU                          -0.935855     -0.988270     -0.933699
# vibration_x_VIBRATION                 -0.431597     -0.450512     -0.426181
# vibration_y_VIBRATION                 -0.402975     -0.416321     -0.401180
# vibration_z_VIBRATION                 -0.396219     -0.397506     -0.372444
# accel_cal_y_SENSOR_OFFSETS            -0.131991     -0.160570     -0.143621
# accel_cal_x_SENSOR_OFFSETS             0.010977      0.019050      0.014215
# accel_cal_z_SENSOR_OFFSETS             0.051639      0.049093      0.045976
# chan12_raw_RC_CHANNELS                 0.125074      0.137201      0.135378
# chan13_raw_RC_CHANNELS                -0.599449     -0.640238     -0.596799
# chan14_raw_RC_CHANNELS                -0.602973     -0.644312     -0.601861
# chan15_raw_RC_CHANNELS                -0.151766     -0.180760     -0.163353
# chan16_raw_RC_CHANNELS                -0.152338     -0.181118     -0.163785
# chancount_RC_CHANNELS                 -0.152349     -0.181123     -0.163823
# roll_ATTITUDE                         -0.946751     -0.992577     -0.933685
# pitch_ATTITUDE                         0.959993      0.943396      0.851216
# yaw_ATTITUDE                           0.112345      0.116478      0.100951
# x_LOCAL_POSITION_NED                   0.136517      0.147199      0.129018
# vx_LOCAL_POSITION_NED                  0.011002      0.001998      0.003014
# vy_LOCAL_POSITION_NED                  0.022949      0.002181      0.017855
# vx_GLOBAL_POSITION_INT                 0.011035      0.002030      0.003050
# vy_GLOBAL_POSITION_INT                 0.022935      0.002158      0.017851
# mag_ofs_x_SENSOR_OFFSETS               0.133580      0.149971      0.149615
# mag_ofs_y_SENSOR_OFFSETS              -0.251297     -0.290486     -0.273965
# servo3_raw_SERVO_OUTPUT_RAW           -0.793741     -0.880806     -0.842262
# servo8_raw_SERVO_OUTPUT_RAW           -0.178711     -0.172637     -0.163283
# airspeed_VFR_HUD                      -0.345225     -0.297218     -0.258559
# groundspeed_VFR_HUD                   -0.368727     -0.321843     -0.275701
# Vservo_POWER_STATUS                   -0.158072     -0.165224     -0.149458
# voltages1_BATTERY_STATUS              -0.010419     -0.026694     -0.036832
# nav_bearing_NAV_CONTROLLER_OUTPUT      0.175015      0.180166      0.156586
# nav_pitch_NAV_CONTROLLER_OUTPUT        0.276891      0.146613      0.137689
# press_abs_SCALED_PRESSURE              0.211325      0.230879      0.209022
# loginfo                               -0.576544     -0.617267     -0.575167
#
#                                    xgyro_RAW_IMU  ygyro_RAW_IMU  \
# xacc_RAW_IMU                           -0.017787      -0.002280
# zacc_RAW_IMU                           -0.004600      -0.009728
# yacc_RAW_IMU                           -0.018874       0.003055
# xgyro_RAW_IMU                           1.000000      -0.046434
# ygyro_RAW_IMU                          -0.046434       1.000000
# zgyro_RAW_IMU                           0.011199      -0.019859
# xmag_RAW_IMU                           -0.001055       0.028601
# ymag_RAW_IMU                           -0.004410       0.000374
# zmag_RAW_IMU                            0.008657       0.003252
# vibration_x_VIBRATION                   0.019614      -0.006683
# vibration_y_VIBRATION                   0.018383       0.000222
# vibration_z_VIBRATION                   0.018030       0.012363
# accel_cal_y_SENSOR_OFFSETS             -0.002810      -0.009305
# accel_cal_x_SENSOR_OFFSETS              0.000407       0.001130
# accel_cal_z_SENSOR_OFFSETS              0.003456       0.003520
# chan12_raw_RC_CHANNELS                  0.007844       0.001612
# chan13_raw_RC_CHANNELS                 -0.013036      -0.038512
# chan14_raw_RC_CHANNELS                 -0.012279      -0.040353
# chan15_raw_RC_CHANNELS                 -0.002592      -0.011550
# chan16_raw_RC_CHANNELS                 -0.002651      -0.011390
# chancount_RC_CHANNELS                  -0.002662      -0.011437
# roll_ATTITUDE                           0.018297       0.002232
# pitch_ATTITUDE                         -0.009489       0.003508
# yaw_ATTITUDE                            0.008066       0.018243
# x_LOCAL_POSITION_NED                   -0.000651       0.010833
# vx_LOCAL_POSITION_NED                  -0.012046       0.014518
# vy_LOCAL_POSITION_NED                  -0.020899      -0.011304
# vx_GLOBAL_POSITION_INT                 -0.011837       0.014271
# vy_GLOBAL_POSITION_INT                 -0.020553      -0.011034
# mag_ofs_x_SENSOR_OFFSETS               -0.003701       0.022180
# mag_ofs_y_SENSOR_OFFSETS                0.001488      -0.027319
# servo3_raw_SERVO_OUTPUT_RAW             0.000439      -0.007598
# servo8_raw_SERVO_OUTPUT_RAW             0.008623      -0.018440
# airspeed_VFR_HUD                       -0.002740      -0.005352
# groundspeed_VFR_HUD                     0.004956       0.008054
# Vservo_POWER_STATUS                    -0.016092      -0.001249
# voltages1_BATTERY_STATUS               -0.003316      -0.005196
# nav_bearing_NAV_CONTROLLER_OUTPUT       0.007753       0.016724
# nav_pitch_NAV_CONTROLLER_OUTPUT         0.002546       0.060319
# press_abs_SCALED_PRESSURE               0.002122       0.018655
# loginfo                                -0.013720      -0.034611
#
#                                    zgyro_RAW_IMU  xmag_RAW_IMU  ymag_RAW_IMU  \
# xacc_RAW_IMU                           -0.015328     -0.128186      0.143916
# zacc_RAW_IMU                           -0.015861     -0.113225      0.140010
# yacc_RAW_IMU                           -0.011300     -0.083434      0.070075
# xgyro_RAW_IMU                           0.011199     -0.001055     -0.004410
# ygyro_RAW_IMU                          -0.019859      0.028601      0.000374
# zgyro_RAW_IMU                           1.000000      0.009639      0.018192
# xmag_RAW_IMU                            0.009639      1.000000      0.189136
# ymag_RAW_IMU                            0.018192      0.189136      1.000000
# zmag_RAW_IMU                            0.012448      0.119810     -0.145998
# vibration_x_VIBRATION                   0.009457     -0.099960     -0.083338
# vibration_y_VIBRATION                   0.011119     -0.005845     -0.047234
# vibration_z_VIBRATION                   0.024307      0.045276     -0.063640
# accel_cal_y_SENSOR_OFFSETS              0.002183      0.033497      0.009008
# accel_cal_x_SENSOR_OFFSETS              0.001781     -0.034772      0.023900
# accel_cal_z_SENSOR_OFFSETS             -0.004829     -0.012802      0.015086
# chan12_raw_RC_CHANNELS                  0.000976     -0.113804     -0.018150
# chan13_raw_RC_CHANNELS                 -0.016911      0.051938     -0.106627
# chan14_raw_RC_CHANNELS                 -0.015867      0.059627     -0.104255
# chan15_raw_RC_CHANNELS                  0.000725      0.032340     -0.004667
# chan16_raw_RC_CHANNELS                  0.001220      0.033686     -0.004290
# chancount_RC_CHANNELS                   0.001145      0.032921     -0.004463
# roll_ATTITUDE                           0.021724      0.115079     -0.126917
# pitch_ATTITUDE                         -0.014384     -0.133665      0.149175
# yaw_ATTITUDE                            0.003136      0.372448      0.472084
# x_LOCAL_POSITION_NED                   -0.012369      0.031512      0.006304
# vx_LOCAL_POSITION_NED                  -0.003053      0.338512     -0.032548
# vy_LOCAL_POSITION_NED                  -0.005330     -0.209718     -0.382606
# vx_GLOBAL_POSITION_INT                 -0.003090      0.338646     -0.032405
# vy_GLOBAL_POSITION_INT                 -0.005351     -0.209727     -0.382286
# mag_ofs_x_SENSOR_OFFSETS               -0.016941      0.100585      0.020340
# mag_ofs_y_SENSOR_OFFSETS               -0.000796     -0.127769     -0.028379
# servo3_raw_SERVO_OUTPUT_RAW            -0.017880      0.032836     -0.148895
# servo8_raw_SERVO_OUTPUT_RAW            -0.012945     -0.146576     -0.029728
# airspeed_VFR_HUD                       -0.000987     -0.044270     -0.012169
# groundspeed_VFR_HUD                     0.013308     -0.034812     -0.029449
# Vservo_POWER_STATUS                    -0.011980      0.028235     -0.022000
# voltages1_BATTERY_STATUS                0.004324      0.196355      0.086610
# nav_bearing_NAV_CONTROLLER_OUTPUT       0.000607      0.360851      0.479088
# nav_pitch_NAV_CONTROLLER_OUTPUT        -0.042359     -0.056520      0.024949
# press_abs_SCALED_PRESSURE               0.011250      0.153634      0.073696
# loginfo                                -0.017009      0.036688     -0.101859
#
#                                    zmag_RAW_IMU  vibration_x_VIBRATION  \
# xacc_RAW_IMU                          -0.935855              -0.431597
# zacc_RAW_IMU                          -0.988270              -0.450512
# yacc_RAW_IMU                          -0.933699              -0.426181
# xgyro_RAW_IMU                          0.008657               0.019614
# ygyro_RAW_IMU                          0.003252              -0.006683
# zgyro_RAW_IMU                          0.012448               0.009457
# xmag_RAW_IMU                           0.119810              -0.099960
# ymag_RAW_IMU                          -0.145998              -0.083338
# zmag_RAW_IMU                           1.000000               0.452520
# vibration_x_VIBRATION                  0.452520               1.000000
# vibration_y_VIBRATION                  0.426565               0.746186
# vibration_z_VIBRATION                  0.407783               0.621728
# accel_cal_y_SENSOR_OFFSETS             0.148674               0.132959
# accel_cal_x_SENSOR_OFFSETS            -0.015189               0.074752
# accel_cal_z_SENSOR_OFFSETS            -0.043867              -0.024695
# chan12_raw_RC_CHANNELS                -0.155092               0.069756
# chan13_raw_RC_CHANNELS                 0.638653               0.158753
# chan14_raw_RC_CHANNELS                 0.643489               0.165693
# chan15_raw_RC_CHANNELS                 0.167827               0.123017
# chan16_raw_RC_CHANNELS                 0.168301               0.124702
# chancount_RC_CHANNELS                  0.168255               0.124959
# roll_ATTITUDE                          0.988016               0.445422
# pitch_ATTITUDE                        -0.935908              -0.431452
# yaw_ATTITUDE                          -0.117459              -0.059540
# x_LOCAL_POSITION_NED                  -0.144788              -0.277097
# vx_LOCAL_POSITION_NED                 -0.025095              -0.010243
# vy_LOCAL_POSITION_NED                  0.004392              -0.004924
# vx_GLOBAL_POSITION_INT                -0.025242              -0.010292
# vy_GLOBAL_POSITION_INT                 0.004420              -0.004888
# mag_ofs_x_SENSOR_OFFSETS              -0.133481              -0.252987
# mag_ofs_y_SENSOR_OFFSETS               0.302087               0.320707
# servo3_raw_SERVO_OUTPUT_RAW            0.870120               0.394014
# servo8_raw_SERVO_OUTPUT_RAW            0.167566               0.271531
# airspeed_VFR_HUD                       0.302172               0.161823
# groundspeed_VFR_HUD                    0.326310               0.251369
# Vservo_POWER_STATUS                    0.153082              -0.289403
# voltages1_BATTERY_STATUS               0.032031               0.077210
# nav_bearing_NAV_CONTROLLER_OUTPUT     -0.180339              -0.086490
# nav_pitch_NAV_CONTROLLER_OUTPUT       -0.147701              -0.090403
# press_abs_SCALED_PRESSURE             -0.206731              -0.178506
# loginfo                                0.623608               0.164732
#
#                                    vibration_y_VIBRATION  \
# xacc_RAW_IMU                                   -0.402975
# zacc_RAW_IMU                                   -0.416321
# yacc_RAW_IMU                                   -0.401180
# xgyro_RAW_IMU                                   0.018383
# ygyro_RAW_IMU                                   0.000222
# zgyro_RAW_IMU                                   0.011119
# xmag_RAW_IMU                                   -0.005845
# ymag_RAW_IMU                                   -0.047234
# zmag_RAW_IMU                                    0.426565
# vibration_x_VIBRATION                           0.746186
# vibration_y_VIBRATION                           1.000000
# vibration_z_VIBRATION                           0.762586
# accel_cal_y_SENSOR_OFFSETS                      0.107328
# accel_cal_x_SENSOR_OFFSETS                     -0.010678
# accel_cal_z_SENSOR_OFFSETS                      0.013146
# chan12_raw_RC_CHANNELS                          0.065961
# chan13_raw_RC_CHANNELS                          0.010836
# chan14_raw_RC_CHANNELS                          0.012055
# chan15_raw_RC_CHANNELS                          0.081963
# chan16_raw_RC_CHANNELS                          0.082609
# chancount_RC_CHANNELS                           0.081996
# roll_ATTITUDE                                   0.416693
# pitch_ATTITUDE                                 -0.392399
# yaw_ATTITUDE                                   -0.033147
# x_LOCAL_POSITION_NED                           -0.224377
# vx_LOCAL_POSITION_NED                          -0.004310
# vy_LOCAL_POSITION_NED                           0.014059
# vx_GLOBAL_POSITION_INT                         -0.004350
# vy_GLOBAL_POSITION_INT                          0.014086
# mag_ofs_x_SENSOR_OFFSETS                       -0.138778
# mag_ofs_y_SENSOR_OFFSETS                        0.096753
# servo3_raw_SERVO_OUTPUT_RAW                     0.388756
# servo8_raw_SERVO_OUTPUT_RAW                     0.173216
# airspeed_VFR_HUD                                0.090101
# groundspeed_VFR_HUD                             0.216946
# Vservo_POWER_STATUS                            -0.273710
# voltages1_BATTERY_STATUS                        0.057371
# nav_bearing_NAV_CONTROLLER_OUTPUT              -0.058112
# nav_pitch_NAV_CONTROLLER_OUTPUT                -0.062627
# press_abs_SCALED_PRESSURE                      -0.072806
# loginfo                                         0.012891
#
#                                    vibration_z_VIBRATION  \
# xacc_RAW_IMU                                   -0.396219
# zacc_RAW_IMU                                   -0.397506
# yacc_RAW_IMU                                   -0.372444
# xgyro_RAW_IMU                                   0.018030
# ygyro_RAW_IMU                                   0.012363
# zgyro_RAW_IMU                                   0.024307
# xmag_RAW_IMU                                    0.045276
# ymag_RAW_IMU                                   -0.063640
# zmag_RAW_IMU                                    0.407783
# vibration_x_VIBRATION                           0.621728
# vibration_y_VIBRATION                           0.762586
# vibration_z_VIBRATION                           1.000000
# accel_cal_y_SENSOR_OFFSETS                      0.012638
# accel_cal_x_SENSOR_OFFSETS                      0.037446
# accel_cal_z_SENSOR_OFFSETS                     -0.005279
# chan12_raw_RC_CHANNELS                         -0.003437
# chan13_raw_RC_CHANNELS                         -0.122814
# chan14_raw_RC_CHANNELS                         -0.124806
# chan15_raw_RC_CHANNELS                         -0.004472
# chan16_raw_RC_CHANNELS                         -0.004039
# chancount_RC_CHANNELS                          -0.004271
# roll_ATTITUDE                                   0.397700
# pitch_ATTITUDE                                 -0.381788
# yaw_ATTITUDE                                   -0.049562
# x_LOCAL_POSITION_NED                           -0.201218
# vx_LOCAL_POSITION_NED                           0.008779
# vy_LOCAL_POSITION_NED                          -0.001930
# vx_GLOBAL_POSITION_INT                          0.008774
# vy_GLOBAL_POSITION_INT                         -0.001912
# mag_ofs_x_SENSOR_OFFSETS                        0.023688
# mag_ofs_y_SENSOR_OFFSETS                       -0.051837
# servo3_raw_SERVO_OUTPUT_RAW                     0.417548
# servo8_raw_SERVO_OUTPUT_RAW                    -0.006542
# airspeed_VFR_HUD                                0.010105
# groundspeed_VFR_HUD                             0.190892
# Vservo_POWER_STATUS                            -0.124551
# voltages1_BATTERY_STATUS                        0.018368
# nav_bearing_NAV_CONTROLLER_OUTPUT              -0.073684
# nav_pitch_NAV_CONTROLLER_OUTPUT                -0.095891
# press_abs_SCALED_PRESSURE                       0.010140
# loginfo                                        -0.125071
#
#                                    accel_cal_y_SENSOR_OFFSETS  \
# xacc_RAW_IMU                                        -0.131991
# zacc_RAW_IMU                                        -0.160570
# yacc_RAW_IMU                                        -0.143621
# xgyro_RAW_IMU                                       -0.002810
# ygyro_RAW_IMU                                       -0.009305
# zgyro_RAW_IMU                                        0.002183
# xmag_RAW_IMU                                         0.033497
# ymag_RAW_IMU                                         0.009008
# zmag_RAW_IMU                                         0.148674
# vibration_x_VIBRATION                                0.132959
# vibration_y_VIBRATION                                0.107328
# vibration_z_VIBRATION                                0.012638
# accel_cal_y_SENSOR_OFFSETS                           1.000000
# accel_cal_x_SENSOR_OFFSETS                          -0.013987
# accel_cal_z_SENSOR_OFFSETS                          -0.255569
# chan12_raw_RC_CHANNELS                               0.031091
# chan13_raw_RC_CHANNELS                               0.241926
# chan14_raw_RC_CHANNELS                               0.248191
# chan15_raw_RC_CHANNELS                               0.875286
# chan16_raw_RC_CHANNELS                               0.885497
# chancount_RC_CHANNELS                                0.885915
# roll_ATTITUDE                                        0.147727
# pitch_ATTITUDE                                      -0.130218
# yaw_ATTITUDE                                        -0.139384
# x_LOCAL_POSITION_NED                                 0.047065
# vx_LOCAL_POSITION_NED                               -0.003101
# vy_LOCAL_POSITION_NED                               -0.003309
# vx_GLOBAL_POSITION_INT                              -0.003261
# vy_GLOBAL_POSITION_INT                              -0.003135
# mag_ofs_x_SENSOR_OFFSETS                            -0.148879
# mag_ofs_y_SENSOR_OFFSETS                             0.154998
# servo3_raw_SERVO_OUTPUT_RAW                          0.101295
# servo8_raw_SERVO_OUTPUT_RAW                         -0.136188
# airspeed_VFR_HUD                                     0.061180
# groundspeed_VFR_HUD                                  0.033959
# Vservo_POWER_STATUS                                 -0.000066
# voltages1_BATTERY_STATUS                             0.095186
# nav_bearing_NAV_CONTROLLER_OUTPUT                   -0.146494
# nav_pitch_NAV_CONTROLLER_OUTPUT                      0.011926
# press_abs_SCALED_PRESSURE                           -0.072035
# loginfo                                              0.243461
#
#                                    accel_cal_x_SENSOR_OFFSETS  \
# xacc_RAW_IMU                                         0.010977
# zacc_RAW_IMU                                         0.019050
# yacc_RAW_IMU                                         0.014215
# xgyro_RAW_IMU                                        0.000407
# ygyro_RAW_IMU                                        0.001130
# zgyro_RAW_IMU                                        0.001781
# xmag_RAW_IMU                                        -0.034772
# ymag_RAW_IMU                                         0.023900
# zmag_RAW_IMU                                        -0.015189
# vibration_x_VIBRATION                                0.074752
# vibration_y_VIBRATION                               -0.010678
# vibration_z_VIBRATION                                0.037446
# accel_cal_y_SENSOR_OFFSETS                          -0.013987
# accel_cal_x_SENSOR_OFFSETS                           1.000000
# accel_cal_z_SENSOR_OFFSETS                           0.065662
# chan12_raw_RC_CHANNELS                               0.003069
# chan13_raw_RC_CHANNELS                              -0.034887
# chan14_raw_RC_CHANNELS                              -0.031012
# chan15_raw_RC_CHANNELS                              -0.116284
# chan16_raw_RC_CHANNELS                              -0.108390
# chancount_RC_CHANNELS                               -0.106752
# roll_ATTITUDE                                       -0.017592
# pitch_ATTITUDE                                       0.008209
# yaw_ATTITUDE                                         0.041702
# x_LOCAL_POSITION_NED                                -0.008276
# vx_LOCAL_POSITION_NED                               -0.007032
# vy_LOCAL_POSITION_NED                               -0.002553
# vx_GLOBAL_POSITION_INT                              -0.007020
# vy_GLOBAL_POSITION_INT                              -0.002550
# mag_ofs_x_SENSOR_OFFSETS                            -0.024421
# mag_ofs_y_SENSOR_OFFSETS                             0.161813
# servo3_raw_SERVO_OUTPUT_RAW                         -0.016738
# servo8_raw_SERVO_OUTPUT_RAW                          0.016431
# airspeed_VFR_HUD                                    -0.002779
# groundspeed_VFR_HUD                                  0.000056
# Vservo_POWER_STATUS                                 -0.099377
# voltages1_BATTERY_STATUS                             0.022940
# nav_bearing_NAV_CONTROLLER_OUTPUT                    0.043623
# nav_pitch_NAV_CONTROLLER_OUTPUT                     -0.027080
# press_abs_SCALED_PRESSURE                           -0.009837
# loginfo                                             -0.029167
#
#                                    accel_cal_z_SENSOR_OFFSETS  \
# xacc_RAW_IMU                                         0.051639
# zacc_RAW_IMU                                         0.049093
# yacc_RAW_IMU                                         0.045976
# xgyro_RAW_IMU                                        0.003456
# ygyro_RAW_IMU                                        0.003520
# zgyro_RAW_IMU                                       -0.004829
# xmag_RAW_IMU                                        -0.012802
# ymag_RAW_IMU                                         0.015086
# zmag_RAW_IMU                                        -0.043867
# vibration_x_VIBRATION                               -0.024695
# vibration_y_VIBRATION                                0.013146
# vibration_z_VIBRATION                               -0.005279
# accel_cal_y_SENSOR_OFFSETS                          -0.255569
# accel_cal_x_SENSOR_OFFSETS                           0.065662
# accel_cal_z_SENSOR_OFFSETS                           1.000000
# chan12_raw_RC_CHANNELS                               0.028823
# chan13_raw_RC_CHANNELS                              -0.071338
# chan14_raw_RC_CHANNELS                              -0.078413
# chan15_raw_RC_CHANNELS                              -0.275112
# chan16_raw_RC_CHANNELS                              -0.280545
# chancount_RC_CHANNELS                               -0.281069
# roll_ATTITUDE                                       -0.046612
# pitch_ATTITUDE                                       0.048265
# yaw_ATTITUDE                                         0.037554
# x_LOCAL_POSITION_NED                                -0.020934
# vx_LOCAL_POSITION_NED                               -0.005327
# vy_LOCAL_POSITION_NED                               -0.002325
# vx_GLOBAL_POSITION_INT                              -0.005247
# vy_GLOBAL_POSITION_INT                              -0.002388
# mag_ofs_x_SENSOR_OFFSETS                             0.052424
# mag_ofs_y_SENSOR_OFFSETS                            -0.008391
# servo3_raw_SERVO_OUTPUT_RAW                         -0.022320
# servo8_raw_SERVO_OUTPUT_RAW                          0.043212
# airspeed_VFR_HUD                                     0.004775
# groundspeed_VFR_HUD                                  0.012243
# Vservo_POWER_STATUS                                 -0.002072
# voltages1_BATTERY_STATUS                            -0.034075
# nav_bearing_NAV_CONTROLLER_OUTPUT                    0.040527
# nav_pitch_NAV_CONTROLLER_OUTPUT                      0.020006
# press_abs_SCALED_PRESSURE                            0.007458
# loginfo                                             -0.083618
#
#                                    chan12_raw_RC_CHANNELS  \
# xacc_RAW_IMU                                     0.125074
# zacc_RAW_IMU                                     0.137201
# yacc_RAW_IMU                                     0.135378
# xgyro_RAW_IMU                                    0.007844
# ygyro_RAW_IMU                                    0.001612
# zgyro_RAW_IMU                                    0.000976
# xmag_RAW_IMU                                    -0.113804
# ymag_RAW_IMU                                    -0.018150
# zmag_RAW_IMU                                    -0.155092
# vibration_x_VIBRATION                            0.069756
# vibration_y_VIBRATION                            0.065961
# vibration_z_VIBRATION                           -0.003437
# accel_cal_y_SENSOR_OFFSETS                       0.031091
# accel_cal_x_SENSOR_OFFSETS                       0.003069
# accel_cal_z_SENSOR_OFFSETS                       0.028823
# chan12_raw_RC_CHANNELS                           1.000000
# chan13_raw_RC_CHANNELS                           0.017520
# chan14_raw_RC_CHANNELS                          -0.014901
# chan15_raw_RC_CHANNELS                           0.068168
# chan16_raw_RC_CHANNELS                           0.063589
# chancount_RC_CHANNELS                            0.063442
# roll_ATTITUDE                                   -0.142278
# pitch_ATTITUDE                                   0.126782
# yaw_ATTITUDE                                    -0.024678
# x_LOCAL_POSITION_NED                            -0.033962
# vx_LOCAL_POSITION_NED                           -0.009407
# vy_LOCAL_POSITION_NED                            0.013113
# vx_GLOBAL_POSITION_INT                          -0.009396
# vy_GLOBAL_POSITION_INT                           0.013114
# mag_ofs_x_SENSOR_OFFSETS                        -0.106933
# mag_ofs_y_SENSOR_OFFSETS                        -0.098480
# servo3_raw_SERVO_OUTPUT_RAW                     -0.225956
# servo8_raw_SERVO_OUTPUT_RAW                      0.108930
# airspeed_VFR_HUD                                -0.085339
# groundspeed_VFR_HUD                             -0.077418
# Vservo_POWER_STATUS                              0.007575
# voltages1_BATTERY_STATUS                         0.306800
# nav_bearing_NAV_CONTROLLER_OUTPUT               -0.015116
# nav_pitch_NAV_CONTROLLER_OUTPUT                  0.005969
# press_abs_SCALED_PRESSURE                        0.052348
# loginfo                                         -0.150564
#
#                                    chan13_raw_RC_CHANNELS  \
# xacc_RAW_IMU                                    -0.599449
# zacc_RAW_IMU                                    -0.640238
# yacc_RAW_IMU                                    -0.596799
# xgyro_RAW_IMU                                   -0.013036
# ygyro_RAW_IMU                                   -0.038512
# zgyro_RAW_IMU                                   -0.016911
# xmag_RAW_IMU                                     0.051938
# ymag_RAW_IMU                                    -0.106627
# zmag_RAW_IMU                                     0.638653
# vibration_x_VIBRATION                            0.158753
# vibration_y_VIBRATION                            0.010836
# vibration_z_VIBRATION                           -0.122814
# accel_cal_y_SENSOR_OFFSETS                       0.241926
# accel_cal_x_SENSOR_OFFSETS                      -0.034887
# accel_cal_z_SENSOR_OFFSETS                      -0.071338
# chan12_raw_RC_CHANNELS                           0.017520
# chan13_raw_RC_CHANNELS                           1.000000
# chan14_raw_RC_CHANNELS                           0.992752
# chan15_raw_RC_CHANNELS                           0.283299
# chan16_raw_RC_CHANNELS                           0.281742
# chancount_RC_CHANNELS                            0.281721
# roll_ATTITUDE                                    0.626664
# pitch_ATTITUDE                                  -0.603009
# yaw_ATTITUDE                                    -0.169442
# x_LOCAL_POSITION_NED                            -0.077905
# vx_LOCAL_POSITION_NED                           -0.003409
# vy_LOCAL_POSITION_NED                            0.000576
# vx_GLOBAL_POSITION_INT                          -0.003448
# vy_GLOBAL_POSITION_INT                           0.000609
# mag_ofs_x_SENSOR_OFFSETS                        -0.269316
# mag_ofs_y_SENSOR_OFFSETS                         0.418622
# servo3_raw_SERVO_OUTPUT_RAW                      0.435421
# servo8_raw_SERVO_OUTPUT_RAW                      0.297614
# airspeed_VFR_HUD                                 0.439580
# groundspeed_VFR_HUD                              0.324048
# Vservo_POWER_STATUS                              0.260255
# voltages1_BATTERY_STATUS                         0.158656
# nav_bearing_NAV_CONTROLLER_OUTPUT               -0.209111
# nav_pitch_NAV_CONTROLLER_OUTPUT                 -0.114237
# press_abs_SCALED_PRESSURE                       -0.320214
# loginfo                                          0.921441
#
#                                    chan14_raw_RC_CHANNELS  \
# xacc_RAW_IMU                                    -0.602973
# zacc_RAW_IMU                                    -0.644312
# yacc_RAW_IMU                                    -0.601861
# xgyro_RAW_IMU                                   -0.012279
# ygyro_RAW_IMU                                   -0.040353
# zgyro_RAW_IMU                                   -0.015867
# xmag_RAW_IMU                                     0.059627
# ymag_RAW_IMU                                    -0.104255
# zmag_RAW_IMU                                     0.643489
# vibration_x_VIBRATION                            0.165693
# vibration_y_VIBRATION                            0.012055
# vibration_z_VIBRATION                           -0.124806
# accel_cal_y_SENSOR_OFFSETS                       0.248191
# accel_cal_x_SENSOR_OFFSETS                      -0.031012
# accel_cal_z_SENSOR_OFFSETS                      -0.078413
# chan12_raw_RC_CHANNELS                          -0.014901
# chan13_raw_RC_CHANNELS                           0.992752
# chan14_raw_RC_CHANNELS                           1.000000
# chan15_raw_RC_CHANNELS                           0.280148
# chan16_raw_RC_CHANNELS                           0.280682
# chancount_RC_CHANNELS                            0.280677
# roll_ATTITUDE                                    0.631061
# pitch_ATTITUDE                                  -0.604176
# yaw_ATTITUDE                                    -0.166081
# x_LOCAL_POSITION_NED                            -0.074421
# vx_LOCAL_POSITION_NED                           -0.002982
# vy_LOCAL_POSITION_NED                            0.000619
# vx_GLOBAL_POSITION_INT                          -0.003028
# vy_GLOBAL_POSITION_INT                           0.000657
# mag_ofs_x_SENSOR_OFFSETS                        -0.283964
# mag_ofs_y_SENSOR_OFFSETS                         0.419156
# servo3_raw_SERVO_OUTPUT_RAW                      0.434019
# servo8_raw_SERVO_OUTPUT_RAW                      0.292355
# airspeed_VFR_HUD                                 0.435128
# groundspeed_VFR_HUD                              0.318763
# Vservo_POWER_STATUS                              0.244511
# voltages1_BATTERY_STATUS                         0.171212
# nav_bearing_NAV_CONTROLLER_OUTPUT               -0.206013
# nav_pitch_NAV_CONTROLLER_OUTPUT                 -0.105238
# press_abs_SCALED_PRESSURE                       -0.317835
# loginfo                                          0.921116
#
#                                    chan15_raw_RC_CHANNELS  \
# xacc_RAW_IMU                                    -0.151766
# zacc_RAW_IMU                                    -0.180760
# yacc_RAW_IMU                                    -0.163353
# xgyro_RAW_IMU                                   -0.002592
# ygyro_RAW_IMU                                   -0.011550
# zgyro_RAW_IMU                                    0.000725
# xmag_RAW_IMU                                     0.032340
# ymag_RAW_IMU                                    -0.004667
# zmag_RAW_IMU                                     0.167827
# vibration_x_VIBRATION                            0.123017
# vibration_y_VIBRATION                            0.081963
# vibration_z_VIBRATION                           -0.004472
# accel_cal_y_SENSOR_OFFSETS                       0.875286
# accel_cal_x_SENSOR_OFFSETS                      -0.116284
# accel_cal_z_SENSOR_OFFSETS                      -0.275112
# chan12_raw_RC_CHANNELS                           0.068168
# chan13_raw_RC_CHANNELS                           0.283299
# chan14_raw_RC_CHANNELS                           0.280148
# chan15_raw_RC_CHANNELS                           1.000000
# chan16_raw_RC_CHANNELS                           0.997920
# chancount_RC_CHANNELS                            0.997960
# roll_ATTITUDE                                    0.166262
# pitch_ATTITUDE                                  -0.151654
# yaw_ATTITUDE                                    -0.155540
# x_LOCAL_POSITION_NED                             0.042911
# vx_LOCAL_POSITION_NED                           -0.002342
# vy_LOCAL_POSITION_NED                           -0.002689
# vx_GLOBAL_POSITION_INT                          -0.002495
# vy_GLOBAL_POSITION_INT                          -0.002567
# mag_ofs_x_SENSOR_OFFSETS                        -0.113219
# mag_ofs_y_SENSOR_OFFSETS                         0.152410
# servo3_raw_SERVO_OUTPUT_RAW                      0.113557
# servo8_raw_SERVO_OUTPUT_RAW                     -0.153383
# airspeed_VFR_HUD                                 0.069789
# groundspeed_VFR_HUD                              0.040146
# Vservo_POWER_STATUS                              0.052656
# voltages1_BATTERY_STATUS                         0.141052
# nav_bearing_NAV_CONTROLLER_OUTPUT               -0.164035
# nav_pitch_NAV_CONTROLLER_OUTPUT                 -0.003694
# press_abs_SCALED_PRESSURE                       -0.071262
# loginfo                                          0.272317
#
#                                    chan16_raw_RC_CHANNELS  \
# xacc_RAW_IMU                                    -0.152338
# zacc_RAW_IMU                                    -0.181118
# yacc_RAW_IMU                                    -0.163785
# xgyro_RAW_IMU                                   -0.002651
# ygyro_RAW_IMU                                   -0.011390
# zgyro_RAW_IMU                                    0.001220
# xmag_RAW_IMU                                     0.033686
# ymag_RAW_IMU                                    -0.004290
# zmag_RAW_IMU                                     0.168301
# vibration_x_VIBRATION                            0.124702
# vibration_y_VIBRATION                            0.082609
# vibration_z_VIBRATION                           -0.004039
# accel_cal_y_SENSOR_OFFSETS                       0.885497
# accel_cal_x_SENSOR_OFFSETS                      -0.108390
# accel_cal_z_SENSOR_OFFSETS                      -0.280545
# chan12_raw_RC_CHANNELS                           0.063589
# chan13_raw_RC_CHANNELS                           0.281742
# chan14_raw_RC_CHANNELS                           0.280682
# chan15_raw_RC_CHANNELS                           0.997920
# chan16_raw_RC_CHANNELS                           1.000000
# chancount_RC_CHANNELS                            0.999899
# roll_ATTITUDE                                    0.166639
# pitch_ATTITUDE                                  -0.151693
# yaw_ATTITUDE                                    -0.156215
# x_LOCAL_POSITION_NED                             0.043466
# vx_LOCAL_POSITION_NED                           -0.002290
# vy_LOCAL_POSITION_NED                           -0.002697
# vx_GLOBAL_POSITION_INT                          -0.002451
# vy_GLOBAL_POSITION_INT                          -0.002566
# mag_ofs_x_SENSOR_OFFSETS                        -0.114909
# mag_ofs_y_SENSOR_OFFSETS                         0.151944
# servo3_raw_SERVO_OUTPUT_RAW                      0.112647
# servo8_raw_SERVO_OUTPUT_RAW                     -0.153681
# airspeed_VFR_HUD                                 0.070142
# groundspeed_VFR_HUD                              0.040443
# Vservo_POWER_STATUS                              0.051786
# voltages1_BATTERY_STATUS                         0.144232
# nav_bearing_NAV_CONTROLLER_OUTPUT               -0.164723
# nav_pitch_NAV_CONTROLLER_OUTPUT                 -0.002850
# press_abs_SCALED_PRESSURE                       -0.070891
# loginfo                                          0.272852
#
#                                    chancount_RC_CHANNELS  roll_ATTITUDE  \
# xacc_RAW_IMU                                   -0.152349      -0.946751
# zacc_RAW_IMU                                   -0.181123      -0.992577
# yacc_RAW_IMU                                   -0.163823      -0.933685
# xgyro_RAW_IMU                                  -0.002662       0.018297
# ygyro_RAW_IMU                                  -0.011437       0.002232
# zgyro_RAW_IMU                                   0.001145       0.021724
# xmag_RAW_IMU                                    0.032921       0.115079
# ymag_RAW_IMU                                   -0.004463      -0.126917
# zmag_RAW_IMU                                    0.168255       0.988016
# vibration_x_VIBRATION                           0.124959       0.445422
# vibration_y_VIBRATION                           0.081996       0.416693
# vibration_z_VIBRATION                          -0.004271       0.397700
# accel_cal_y_SENSOR_OFFSETS                      0.885915       0.147727
# accel_cal_x_SENSOR_OFFSETS                     -0.106752      -0.017592
# accel_cal_z_SENSOR_OFFSETS                     -0.281069      -0.046612
# chan12_raw_RC_CHANNELS                          0.063442      -0.142278
# chan13_raw_RC_CHANNELS                          0.281721       0.626664
# chan14_raw_RC_CHANNELS                          0.280677       0.631061
# chan15_raw_RC_CHANNELS                          0.997960       0.166262
# chan16_raw_RC_CHANNELS                          0.999899       0.166639
# chancount_RC_CHANNELS                           1.000000       0.166644
# roll_ATTITUDE                                   0.166644       1.000000
# pitch_ATTITUDE                                 -0.151767      -0.949246
# yaw_ATTITUDE                                   -0.156025      -0.110569
# x_LOCAL_POSITION_NED                            0.043165      -0.144069
# vx_LOCAL_POSITION_NED                          -0.002364      -0.002060
# vy_LOCAL_POSITION_NED                          -0.002751      -0.004364
# vx_GLOBAL_POSITION_INT                         -0.002525      -0.002027
# vy_GLOBAL_POSITION_INT                         -0.002620      -0.004184
# mag_ofs_x_SENSOR_OFFSETS                       -0.115536      -0.146987
# mag_ofs_y_SENSOR_OFFSETS                        0.152987       0.283435
# servo3_raw_SERVO_OUTPUT_RAW                     0.112761       0.883843
# servo8_raw_SERVO_OUTPUT_RAW                    -0.153696       0.168708
# airspeed_VFR_HUD                                0.070234       0.289146
# groundspeed_VFR_HUD                             0.040533       0.312668
# Vservo_POWER_STATUS                             0.052230       0.163843
# voltages1_BATTERY_STATUS                        0.144695       0.021267
# nav_bearing_NAV_CONTROLLER_OUTPUT              -0.164535      -0.174749
# nav_pitch_NAV_CONTROLLER_OUTPUT                -0.003055      -0.148021
# press_abs_SCALED_PRESSURE                      -0.071238      -0.225286
# loginfo                                         0.272875       0.605257
#
#                                    pitch_ATTITUDE  yaw_ATTITUDE  \
# xacc_RAW_IMU                             0.959993      0.112345
# zacc_RAW_IMU                             0.943396      0.116478
# yacc_RAW_IMU                             0.851216      0.100951
# xgyro_RAW_IMU                           -0.009489      0.008066
# ygyro_RAW_IMU                            0.003508      0.018243
# zgyro_RAW_IMU                           -0.014384      0.003136
# xmag_RAW_IMU                            -0.133665      0.372448
# ymag_RAW_IMU                             0.149175      0.472084
# zmag_RAW_IMU                            -0.935908     -0.117459
# vibration_x_VIBRATION                   -0.431452     -0.059540
# vibration_y_VIBRATION                   -0.392399     -0.033147
# vibration_z_VIBRATION                   -0.381788     -0.049562
# accel_cal_y_SENSOR_OFFSETS              -0.130218     -0.139384
# accel_cal_x_SENSOR_OFFSETS               0.008209      0.041702
# accel_cal_z_SENSOR_OFFSETS               0.048265      0.037554
# chan12_raw_RC_CHANNELS                   0.126782     -0.024678
# chan13_raw_RC_CHANNELS                  -0.603009     -0.169442
# chan14_raw_RC_CHANNELS                  -0.604176     -0.166081
# chan15_raw_RC_CHANNELS                  -0.151654     -0.155540
# chan16_raw_RC_CHANNELS                  -0.151693     -0.156215
# chancount_RC_CHANNELS                   -0.151767     -0.156025
# roll_ATTITUDE                           -0.949246     -0.110569
# pitch_ATTITUDE                           1.000000      0.110896
# yaw_ATTITUDE                             0.110896      1.000000
# x_LOCAL_POSITION_NED                     0.141799      0.119735
# vx_LOCAL_POSITION_NED                    0.009032      0.073410
# vy_LOCAL_POSITION_NED                    0.024289     -0.184259
# vx_GLOBAL_POSITION_INT                   0.008796      0.073424
# vy_GLOBAL_POSITION_INT                   0.024442     -0.184380
# mag_ofs_x_SENSOR_OFFSETS                 0.138192      0.096183
# mag_ofs_y_SENSOR_OFFSETS                -0.275781     -0.076550
# servo3_raw_SERVO_OUTPUT_RAW             -0.800935     -0.127995
# servo8_raw_SERVO_OUTPUT_RAW             -0.180301     -0.060185
# airspeed_VFR_HUD                        -0.356525     -0.174933
# groundspeed_VFR_HUD                     -0.376188     -0.183777
# Vservo_POWER_STATUS                     -0.155062     -0.044216
# voltages1_BATTERY_STATUS                 0.010290      0.118010
# nav_bearing_NAV_CONTROLLER_OUTPUT        0.173982      0.986517
# nav_pitch_NAV_CONTROLLER_OUTPUT          0.392577      0.037926
# press_abs_SCALED_PRESSURE                0.223544      0.141665
# loginfo                                 -0.580719     -0.148532
#
#                                    x_LOCAL_POSITION_NED  \
# xacc_RAW_IMU                                   0.136517
# zacc_RAW_IMU                                   0.147199
# yacc_RAW_IMU                                   0.129018
# xgyro_RAW_IMU                                 -0.000651
# ygyro_RAW_IMU                                  0.010833
# zgyro_RAW_IMU                                 -0.012369
# xmag_RAW_IMU                                   0.031512
# ymag_RAW_IMU                                   0.006304
# zmag_RAW_IMU                                  -0.144788
# vibration_x_VIBRATION                         -0.277097
# vibration_y_VIBRATION                         -0.224377
# vibration_z_VIBRATION                         -0.201218
# accel_cal_y_SENSOR_OFFSETS                     0.047065
# accel_cal_x_SENSOR_OFFSETS                    -0.008276
# accel_cal_z_SENSOR_OFFSETS                    -0.020934
# chan12_raw_RC_CHANNELS                        -0.033962
# chan13_raw_RC_CHANNELS                        -0.077905
# chan14_raw_RC_CHANNELS                        -0.074421
# chan15_raw_RC_CHANNELS                         0.042911
# chan16_raw_RC_CHANNELS                         0.043466
# chancount_RC_CHANNELS                          0.043165
# roll_ATTITUDE                                 -0.144069
# pitch_ATTITUDE                                 0.141799
# yaw_ATTITUDE                                   0.119735
# x_LOCAL_POSITION_NED                           1.000000
# vx_LOCAL_POSITION_NED                          0.012605
# vy_LOCAL_POSITION_NED                          0.093053
# vx_GLOBAL_POSITION_INT                         0.012472
# vy_GLOBAL_POSITION_INT                         0.093081
# mag_ofs_x_SENSOR_OFFSETS                       0.117681
# mag_ofs_y_SENSOR_OFFSETS                      -0.125818
# servo3_raw_SERVO_OUTPUT_RAW                   -0.124489
# servo8_raw_SERVO_OUTPUT_RAW                   -0.194094
# airspeed_VFR_HUD                              -0.382632
# groundspeed_VFR_HUD                           -0.423502
# Vservo_POWER_STATUS                            0.015473
# voltages1_BATTERY_STATUS                       0.038901
# nav_bearing_NAV_CONTROLLER_OUTPUT              0.128365
# nav_pitch_NAV_CONTROLLER_OUTPUT                0.029853
# press_abs_SCALED_PRESSURE                      0.182414
# loginfo                                       -0.082785
#
#                                    vx_LOCAL_POSITION_NED  \
# xacc_RAW_IMU                                    0.011002
# zacc_RAW_IMU                                    0.001998
# yacc_RAW_IMU                                    0.003014
# xgyro_RAW_IMU                                  -0.012046
# ygyro_RAW_IMU                                   0.014518
# zgyro_RAW_IMU                                  -0.003053
# xmag_RAW_IMU                                    0.338512
# ymag_RAW_IMU                                   -0.032548
# zmag_RAW_IMU                                   -0.025095
# vibration_x_VIBRATION                          -0.010243
# vibration_y_VIBRATION                          -0.004310
# vibration_z_VIBRATION                           0.008779
# accel_cal_y_SENSOR_OFFSETS                     -0.003101
# accel_cal_x_SENSOR_OFFSETS                     -0.007032
# ...
# chan14_raw_RC_CHANNELS                     0.435128             0.318763
# chan15_raw_RC_CHANNELS                     0.069789             0.040146
# chan16_raw_RC_CHANNELS                     0.070142             0.040443
# chancount_RC_CHANNELS                      0.070234             0.040533
# roll_ATTITUDE                              0.289146             0.312668
# pitch_ATTITUDE                            -0.356525            -0.376188
# yaw_ATTITUDE                              -0.174933            -0.183777
# x_LOCAL_POSITION_NED                      -0.382632            -0.423502
# vx_LOCAL_POSITION_NED                      0.034532             0.035171
# vy_LOCAL_POSITION_NED                      0.007580             0.004415
# vx_GLOBAL_POSITION_INT                     0.034458             0.035112
# vy_GLOBAL_POSITION_INT                     0.007562             0.004389
# mag_ofs_x_SENSOR_OFFSETS                  -0.076565            -0.049017
# mag_ofs_y_SENSOR_OFFSETS                   0.324605             0.272744
# servo3_raw_SERVO_OUTPUT_RAW                0.139226             0.192350
# servo8_raw_SERVO_OUTPUT_RAW                0.269061             0.238291
# airspeed_VFR_HUD                           1.000000             0.952702
# groundspeed_VFR_HUD                        0.952702             1.000000
# Vservo_POWER_STATUS                       -0.003366            -0.032396
# voltages1_BATTERY_STATUS                  -0.149149            -0.158148
# nav_bearing_NAV_CONTROLLER_OUTPUT         -0.193666            -0.203811
# nav_pitch_NAV_CONTROLLER_OUTPUT           -0.311584            -0.318619
# press_abs_SCALED_PRESSURE                 -0.291152            -0.258149
# loginfo                                    0.467992             0.356766
#
#                                    Vservo_POWER_STATUS  \
# xacc_RAW_IMU                                 -0.158072
# zacc_RAW_IMU                                 -0.165224
# yacc_RAW_IMU                                 -0.149458
# xgyro_RAW_IMU                                -0.016092
# ygyro_RAW_IMU                                -0.001249
# zgyro_RAW_IMU                                -0.011980
# xmag_RAW_IMU                                  0.028235
# ymag_RAW_IMU                                 -0.022000
# zmag_RAW_IMU                                  0.153082
# vibration_x_VIBRATION                        -0.289403
# vibration_y_VIBRATION                        -0.273710
# vibration_z_VIBRATION                        -0.124551
# accel_cal_y_SENSOR_OFFSETS                   -0.000066
# accel_cal_x_SENSOR_OFFSETS                   -0.099377
# accel_cal_z_SENSOR_OFFSETS                   -0.002072
# chan12_raw_RC_CHANNELS                        0.007575
# chan13_raw_RC_CHANNELS                        0.260255
# chan14_raw_RC_CHANNELS                        0.244511
# chan15_raw_RC_CHANNELS                        0.052656
# chan16_raw_RC_CHANNELS                        0.051786
# chancount_RC_CHANNELS                         0.052230
# roll_ATTITUDE                                 0.163843
# pitch_ATTITUDE                               -0.155062
# yaw_ATTITUDE                                 -0.044216
# x_LOCAL_POSITION_NED                          0.015473
# vx_LOCAL_POSITION_NED                        -0.002376
# vy_LOCAL_POSITION_NED                        -0.002603
# vx_GLOBAL_POSITION_INT                       -0.002344
# vy_GLOBAL_POSITION_INT                       -0.002601
# mag_ofs_x_SENSOR_OFFSETS                      0.133481
# mag_ofs_y_SENSOR_OFFSETS                     -0.323567
# servo3_raw_SERVO_OUTPUT_RAW                   0.123367
# servo8_raw_SERVO_OUTPUT_RAW                  -0.158594
# airspeed_VFR_HUD                             -0.003366
# groundspeed_VFR_HUD                          -0.032396
# Vservo_POWER_STATUS                           1.000000
# voltages1_BATTERY_STATUS                      0.246857
# nav_bearing_NAV_CONTROLLER_OUTPUT            -0.055147
# nav_pitch_NAV_CONTROLLER_OUTPUT              -0.025116
# press_abs_SCALED_PRESSURE                    -0.002247
# loginfo                                       0.216155
#
#                                    voltages1_BATTERY_STATUS  \
# xacc_RAW_IMU                                      -0.010419
# zacc_RAW_IMU                                      -0.026694
# yacc_RAW_IMU                                      -0.036832
# xgyro_RAW_IMU                                     -0.003316
# ygyro_RAW_IMU                                     -0.005196
# zgyro_RAW_IMU                                      0.004324
# xmag_RAW_IMU                                       0.196355
# ymag_RAW_IMU                                       0.086610
# zmag_RAW_IMU                                       0.032031
# vibration_x_VIBRATION                              0.077210
# vibration_y_VIBRATION                              0.057371
# vibration_z_VIBRATION                              0.018368
# accel_cal_y_SENSOR_OFFSETS                         0.095186
# accel_cal_x_SENSOR_OFFSETS                         0.022940
# accel_cal_z_SENSOR_OFFSETS                        -0.034075
# chan12_raw_RC_CHANNELS                             0.306800
# chan13_raw_RC_CHANNELS                             0.158656
# chan14_raw_RC_CHANNELS                             0.171212
# chan15_raw_RC_CHANNELS                             0.141052
# chan16_raw_RC_CHANNELS                             0.144232
# chancount_RC_CHANNELS                              0.144695
# roll_ATTITUDE                                      0.021267
# pitch_ATTITUDE                                     0.010290
# yaw_ATTITUDE                                       0.118010
# x_LOCAL_POSITION_NED                               0.038901
# vx_LOCAL_POSITION_NED                             -0.007992
# vy_LOCAL_POSITION_NED                              0.001243
# vx_GLOBAL_POSITION_INT                            -0.008015
# vy_GLOBAL_POSITION_INT                             0.001267
# mag_ofs_x_SENSOR_OFFSETS                          -0.087473
# mag_ofs_y_SENSOR_OFFSETS                          -0.123236
# servo3_raw_SERVO_OUTPUT_RAW                       -0.207888
# servo8_raw_SERVO_OUTPUT_RAW                       -0.003864
# airspeed_VFR_HUD                                  -0.149149
# groundspeed_VFR_HUD                               -0.158148
# Vservo_POWER_STATUS                                0.246857
# voltages1_BATTERY_STATUS                           1.000000
# nav_bearing_NAV_CONTROLLER_OUTPUT                  0.116061
# nav_pitch_NAV_CONTROLLER_OUTPUT                    0.101773
# press_abs_SCALED_PRESSURE                          0.145276
# loginfo                                            0.027445
#
#                                    nav_bearing_NAV_CONTROLLER_OUTPUT  \
# xacc_RAW_IMU                                                0.175015
# zacc_RAW_IMU                                                0.180166
# yacc_RAW_IMU                                                0.156586
# xgyro_RAW_IMU                                               0.007753
# ygyro_RAW_IMU                                               0.016724
# zgyro_RAW_IMU                                               0.000607
# xmag_RAW_IMU                                                0.360851
# ymag_RAW_IMU                                                0.479088
# zmag_RAW_IMU                                               -0.180339
# vibration_x_VIBRATION                                      -0.086490
# vibration_y_VIBRATION                                      -0.058112
# vibration_z_VIBRATION                                      -0.073684
# accel_cal_y_SENSOR_OFFSETS                                 -0.146494
# accel_cal_x_SENSOR_OFFSETS                                  0.043623
# accel_cal_z_SENSOR_OFFSETS                                  0.040527
# chan12_raw_RC_CHANNELS                                     -0.015116
# chan13_raw_RC_CHANNELS                                     -0.209111
# chan14_raw_RC_CHANNELS                                     -0.206013
# chan15_raw_RC_CHANNELS                                     -0.164035
# chan16_raw_RC_CHANNELS                                     -0.164723
# chancount_RC_CHANNELS                                      -0.164535
# roll_ATTITUDE                                              -0.174749
# pitch_ATTITUDE                                              0.173982
# yaw_ATTITUDE                                                0.986517
# x_LOCAL_POSITION_NED                                        0.128365
# vx_LOCAL_POSITION_NED                                       0.072727
# vy_LOCAL_POSITION_NED                                      -0.182464
# vx_GLOBAL_POSITION_INT                                      0.072740
# vy_GLOBAL_POSITION_INT                                     -0.182582
# mag_ofs_x_SENSOR_OFFSETS                                    0.104133
# mag_ofs_y_SENSOR_OFFSETS                                   -0.094756
# servo3_raw_SERVO_OUTPUT_RAW                                -0.184191
# servo8_raw_SERVO_OUTPUT_RAW                                -0.071027
# airspeed_VFR_HUD                                           -0.193666
# groundspeed_VFR_HUD                                        -0.203811
# Vservo_POWER_STATUS                                        -0.055147
# voltages1_BATTERY_STATUS                                    0.116061
# nav_bearing_NAV_CONTROLLER_OUTPUT                           1.000000
# nav_pitch_NAV_CONTROLLER_OUTPUT                             0.046508
# press_abs_SCALED_PRESSURE                                   0.155947
# loginfo                                                    -0.187049
#
#                                    nav_pitch_NAV_CONTROLLER_OUTPUT  \
# xacc_RAW_IMU                                              0.276891
# zacc_RAW_IMU                                              0.146613
# yacc_RAW_IMU                                              0.137689
# xgyro_RAW_IMU                                             0.002546
# ygyro_RAW_IMU                                             0.060319
# zgyro_RAW_IMU                                            -0.042359
# xmag_RAW_IMU                                             -0.056520
# ymag_RAW_IMU                                              0.024949
# zmag_RAW_IMU                                             -0.147701
# vibration_x_VIBRATION                                    -0.090403
# vibration_y_VIBRATION                                    -0.062627
# vibration_z_VIBRATION                                    -0.095891
# accel_cal_y_SENSOR_OFFSETS                                0.011926
# accel_cal_x_SENSOR_OFFSETS                               -0.027080
# accel_cal_z_SENSOR_OFFSETS                                0.020006
# chan12_raw_RC_CHANNELS                                    0.005969
# chan13_raw_RC_CHANNELS                                   -0.114237
# chan14_raw_RC_CHANNELS                                   -0.105238
# chan15_raw_RC_CHANNELS                                   -0.003694
# chan16_raw_RC_CHANNELS                                   -0.002850
# chancount_RC_CHANNELS                                    -0.003055
# roll_ATTITUDE                                            -0.148021
# pitch_ATTITUDE                                            0.392577
# yaw_ATTITUDE                                              0.037926
# x_LOCAL_POSITION_NED                                      0.029853
# vx_LOCAL_POSITION_NED                                     0.023347
# vy_LOCAL_POSITION_NED                                     0.083402
# vx_GLOBAL_POSITION_INT                                    0.022428
# vy_GLOBAL_POSITION_INT                                    0.084003
# mag_ofs_x_SENSOR_OFFSETS                                  0.015704
# mag_ofs_y_SENSOR_OFFSETS                                 -0.058241
# servo3_raw_SERVO_OUTPUT_RAW                              -0.010581
# servo8_raw_SERVO_OUTPUT_RAW                              -0.079836
# airspeed_VFR_HUD                                         -0.311584
# groundspeed_VFR_HUD                                      -0.318619
# Vservo_POWER_STATUS                                      -0.025116
# voltages1_BATTERY_STATUS                                  0.101773
# nav_bearing_NAV_CONTROLLER_OUTPUT                         0.046508
# nav_pitch_NAV_CONTROLLER_OUTPUT                           1.000000
# press_abs_SCALED_PRESSURE                                 0.056028
# loginfo                                                  -0.106804
#
#                                    press_abs_SCALED_PRESSURE   loginfo
# xacc_RAW_IMU                                        0.211325 -0.576544
# zacc_RAW_IMU                                        0.230879 -0.617267
# yacc_RAW_IMU                                        0.209022 -0.575167
# xgyro_RAW_IMU                                       0.002122 -0.013720
# ygyro_RAW_IMU                                       0.018655 -0.034611
# zgyro_RAW_IMU                                       0.011250 -0.017009
# xmag_RAW_IMU                                        0.153634  0.036688
# ymag_RAW_IMU                                        0.073696 -0.101859
# zmag_RAW_IMU                                       -0.206731  0.623608
# vibration_x_VIBRATION                              -0.178506  0.164732
# vibration_y_VIBRATION                              -0.072806  0.012891
# vibration_z_VIBRATION                               0.010140 -0.125071
# accel_cal_y_SENSOR_OFFSETS                         -0.072035  0.243461
# accel_cal_x_SENSOR_OFFSETS                         -0.009837 -0.029167
# accel_cal_z_SENSOR_OFFSETS                          0.007458 -0.083618
# chan12_raw_RC_CHANNELS                              0.052348 -0.150564
# chan13_raw_RC_CHANNELS                             -0.320214  0.921441
# chan14_raw_RC_CHANNELS                             -0.317835  0.921116
# chan15_raw_RC_CHANNELS                             -0.071262  0.272317
# chan16_raw_RC_CHANNELS                             -0.070891  0.272852
# chancount_RC_CHANNELS                              -0.071238  0.272875
# roll_ATTITUDE                                      -0.225286  0.605257
# pitch_ATTITUDE                                      0.223544 -0.580719
# yaw_ATTITUDE                                        0.141665 -0.148532
# x_LOCAL_POSITION_NED                                0.182414 -0.082785
# vx_LOCAL_POSITION_NED                              -0.007154 -0.000498
# vy_LOCAL_POSITION_NED                              -0.012084 -0.000269
# vx_GLOBAL_POSITION_INT                             -0.007135 -0.000544
# vy_GLOBAL_POSITION_INT                             -0.012090 -0.000233
# mag_ofs_x_SENSOR_OFFSETS                            0.136595 -0.105666
# mag_ofs_y_SENSOR_OFFSETS                           -0.282584  0.502740
# servo3_raw_SERVO_OUTPUT_RAW                        -0.209922  0.457942
# servo8_raw_SERVO_OUTPUT_RAW                        -0.168917  0.285255
# airspeed_VFR_HUD                                   -0.291152  0.467992
# groundspeed_VFR_HUD                                -0.258149  0.356766
# Vservo_POWER_STATUS                                -0.002247  0.216155
# voltages1_BATTERY_STATUS                            0.145276  0.027445
# nav_bearing_NAV_CONTROLLER_OUTPUT                   0.155947 -0.187049
# nav_pitch_NAV_CONTROLLER_OUTPUT                     0.056028 -0.106804
# press_abs_SCALED_PRESSURE                           1.000000 -0.328636
# loginfo                                            -0.328636  1.000000

# %%
# heatmap
plt.figure(figsize=(30,15))
cmap = sns.light_palette("navy", as_cmap=True)
sns.heatmap(train_df.corr(), annot=True, cmap=cmap)
plt.show()

# %%
# feature_lable_split
train_x = train_df.iloc[:,0:-1] 
labeled_train_y = train_df.iloc[:,-1]
test_x = test_df.iloc[:,0:-1]
labeled_test_y = test_df.iloc[:,-1]
print(train_x.shape, labeled_train_y.shape, test_x.shape, labeled_test_y.shape) #(1173933, 40) (1173933,) (293484, 40) (293484,)
# Out:
# (1173933, 40) (1173933,) (293484, 40) (293484,)

# %%
# feature data Scaleing 
from sklearn.preprocessing import MinMaxScaler

## train
scaled_train_x = MinMaxScaler().fit_transform(train_x)
scaled_train_x=pd.DataFrame(data=scaled_train_x, columns=train_x.columns)
## test
scaled_test_x = MinMaxScaler().fit_transform(test_x)
scaled_test_x=pd.DataFrame(data=scaled_test_x, columns=train_x.columns)

scaled_train_x.describe()
# Out:
#        xacc_RAW_IMU  zacc_RAW_IMU  yacc_RAW_IMU  xgyro_RAW_IMU  ygyro_RAW_IMU  \
# count  1.173933e+06  1.173933e+06  1.173933e+06   1.173933e+06   1.173933e+06
# mean   4.938230e-01  2.929251e-01  5.376132e-01   4.810818e-01   3.660624e-01
# std    2.193108e-02  4.446633e-02  1.847680e-02   6.381691e-03   5.236376e-03
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00   0.000000e+00
# 25%    4.817992e-01  2.723895e-01  5.283625e-01   4.798768e-01   3.648326e-01
# 50%    4.866576e-01  2.739774e-01  5.306920e-01   4.809272e-01   3.660210e-01
# 75%    4.921206e-01  2.771731e-01  5.356576e-01   4.824900e-01   3.674111e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00   1.000000e+00
#
#        zgyro_RAW_IMU  xmag_RAW_IMU  ymag_RAW_IMU  zmag_RAW_IMU  \
# count   1.173933e+06  1.173933e+06  1.173933e+06  1.173933e+06
# mean    5.879136e-01  5.619067e-01  8.355901e-01  4.325582e-01
# std     5.736472e-03  5.488857e-02  5.479530e-02  4.164295e-02
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     5.872333e-01  5.083772e-01  7.947761e-01  4.445970e-01
# 50%     5.877351e-01  5.457157e-01  8.537992e-01  4.503369e-01
# 75%     5.884549e-01  6.223073e-01  8.636364e-01  4.530821e-01
# max     1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#        vibration_x_VIBRATION  vibration_y_VIBRATION  vibration_z_VIBRATION  \
# count           1.173933e+06           1.173933e+06           1.173933e+06
# mean            5.027124e-02           3.763859e-02           4.602763e-02
# std             4.804586e-02           3.869408e-02           4.970175e-02
# min             0.000000e+00           0.000000e+00           0.000000e+00
# 25%             7.959870e-03           6.582109e-03           1.957860e-02
# 50%             4.002298e-02           2.985162e-02           3.579137e-02
# 75%             8.430492e-02           5.911906e-02           5.512936e-02
# max             1.000000e+00           1.000000e+00           1.000000e+00
#
#        accel_cal_y_SENSOR_OFFSETS  accel_cal_x_SENSOR_OFFSETS  \
# count                1.173933e+06                1.173933e+06
# mean                 5.939645e-01                5.510706e-01
# std                  7.579220e-02                6.265628e-02
# min                  0.000000e+00                0.000000e+00
# 25%                  5.681510e-01                5.536453e-01
# 50%                  5.681510e-01                5.536453e-01
# 75%                  5.681510e-01                5.536453e-01
# max                  1.000000e+00                1.000000e+00
#
#        accel_cal_z_SENSOR_OFFSETS  chan12_raw_RC_CHANNELS  \
# count                1.173933e+06            1.173933e+06
# mean                 4.170027e-01            6.480845e-01
# std                  3.930641e-02            7.992434e-02
# min                  0.000000e+00            0.000000e+00
# 25%                  4.212504e-01            6.693548e-01
# 50%                  4.212504e-01            6.693548e-01
# 75%                  4.212504e-01            6.720430e-01
# max                  1.000000e+00            1.000000e+00
#
#        chan13_raw_RC_CHANNELS  chan14_raw_RC_CHANNELS  chan15_raw_RC_CHANNELS  \
# count            1.173933e+06            1.173933e+06            1.173933e+06
# mean             4.738503e-01            5.274672e-01            9.570726e-02
# std              3.262000e-01            3.606840e-01            2.495076e-01
# min              0.000000e+00            0.000000e+00            0.000000e+00
# 25%              0.000000e+00            0.000000e+00            0.000000e+00
# 50%              7.144907e-01            7.888068e-01            0.000000e+00
# 75%              7.144907e-01            7.888068e-01            0.000000e+00
# max              1.000000e+00            1.000000e+00            1.000000e+00
#
#        chan16_raw_RC_CHANNELS  chancount_RC_CHANNELS  roll_ATTITUDE  \
# count            1.173933e+06           1.173933e+06   1.173933e+06
# mean             9.502661e-02           1.287220e-01   4.341761e-01
# std              2.472529e-01           3.348921e-01   1.423101e-01
# min              0.000000e+00           0.000000e+00   0.000000e+00
# 25%              0.000000e+00           0.000000e+00   4.865808e-01
# 50%              0.000000e+00           0.000000e+00   4.947145e-01
# 75%              0.000000e+00           0.000000e+00   4.986392e-01
# max              1.000000e+00           1.000000e+00   1.000000e+00
#
#        pitch_ATTITUDE  yaw_ATTITUDE  x_LOCAL_POSITION_NED  \
# count    1.173933e+06  1.173933e+06          1.173933e+06
# mean     5.701919e-01  6.094820e-01          5.188612e-01
# std      8.212594e-02  2.650666e-01          8.319294e-02
# min      0.000000e+00  0.000000e+00          0.000000e+00
# 25%      5.269282e-01  4.079197e-01          5.336386e-01
# 50%      5.428127e-01  6.759469e-01          5.451828e-01
# 75%      5.598804e-01  8.842744e-01          5.470456e-01
# max      1.000000e+00  1.000000e+00          1.000000e+00
#
#        vx_LOCAL_POSITION_NED  vy_LOCAL_POSITION_NED  vx_GLOBAL_POSITION_INT  \
# count           1.173933e+06           1.173933e+06            1.173933e+06
# mean            5.954690e-01           5.931750e-01            5.954643e-01
# std             7.623129e-02           5.462300e-02            7.621631e-02
# min             0.000000e+00           0.000000e+00            0.000000e+00
# 25%             5.923119e-01           5.902648e-01            5.923180e-01
# 50%             5.957993e-01           5.929695e-01            5.957993e-01
# 75%             5.989633e-01           5.955240e-01            5.989217e-01
# max             1.000000e+00           1.000000e+00            1.000000e+00
#
#        vy_GLOBAL_POSITION_INT  mag_ofs_x_SENSOR_OFFSETS  \
# count            1.173933e+06              1.173933e+06
# mean             5.931778e-01              6.260617e-01
# std              5.461351e-02              1.003753e-01
# min              0.000000e+00              0.000000e+00
# 25%              5.902887e-01              5.639229e-01
# 50%              5.929956e-01              6.199650e-01
# 75%              5.954936e-01              6.602452e-01
# max              1.000000e+00              1.000000e+00
#
#        mag_ofs_y_SENSOR_OFFSETS  servo3_raw_SERVO_OUTPUT_RAW  \
# count              1.173933e+06                 1.173933e+06
# mean               7.158638e-01                 5.299463e-01
# std                1.223144e-01                 1.923029e-01
# min                0.000000e+00                 0.000000e+00
# 25%                6.348624e-01                 4.776786e-01
# 50%                6.477064e-01                 5.870536e-01
# 75%                8.403670e-01                 6.584821e-01
# max                1.000000e+00                 1.000000e+00
#
#        servo8_raw_SERVO_OUTPUT_RAW  airspeed_VFR_HUD  groundspeed_VFR_HUD  \
# count                 1.173933e+06      1.173933e+06         1.173933e+06
# mean                  1.023201e-01      1.367266e-01         1.044599e-01
# std                   2.558853e-01      2.003677e-01         1.352522e-01
# min                   0.000000e+00      0.000000e+00         0.000000e+00
# 25%                   0.000000e+00      0.000000e+00         3.252164e-03
# 50%                   0.000000e+00      6.979696e-03         8.918711e-03
# 75%                   0.000000e+00      3.305838e-01         2.302108e-01
# max                   1.000000e+00      1.000000e+00         1.000000e+00
#
#        Vservo_POWER_STATUS  voltages1_BATTERY_STATUS  \
# count         1.173933e+06              1.173933e+06
# mean          1.278027e-01              3.654184e-01
# std           3.222227e-01              1.581093e-01
# min           0.000000e+00              0.000000e+00
# 25%           0.000000e+00              3.408833e-01
# 50%           7.415647e-04              3.545740e-01
# 75%           7.601038e-03              3.601146e-01
# max           1.000000e+00              1.000000e+00
#
#        nav_bearing_NAV_CONTROLLER_OUTPUT  nav_pitch_NAV_CONTROLLER_OUTPUT  \
# count                       1.173933e+06                     1.173933e+06
# mean                        6.170910e-01                     6.478341e-01
# std                         2.671767e-01                     2.887244e-02
# min                         0.000000e+00                     0.000000e+00
# 25%                         4.091944e-01                     6.336490e-01
# 50%                         6.941111e-01                     6.538873e-01
# 75%                         8.833333e-01                     6.585425e-01
# max                         1.000000e+00                     1.000000e+00
#
#        press_abs_SCALED_PRESSURE
# count               1.173933e+06
# mean                9.599221e-01
# std                 5.056283e-02
# min                 0.000000e+00
# 25%                 9.434986e-01
# 50%                 9.693433e-01
# 75%                 9.843648e-01
# max                 1.000000e+00

# %% [markdown]
# ## 3. Modeling

# %%
# holdout
from sklearn.model_selection import train_test_split

X_train, X_vaild, y_train, y_vaild = train_test_split(scaled_train_x, labeled_train_y, test_size=0.3, random_state=777, stratify=labeled_train_y) 
print(X_train.shape, y_train.shape, X_vaild.shape, y_vaild.shape) # (821753, 40) (352180, 40) (821753,) (352180,)
# Out:
# (821753, 40) (821753,) (352180, 40) (352180,)

# %%
# RandomForestClassifier Train
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()   # random_state = ?
rf.fit(X_train, y_train)

print(rf.score(X_vaild, y_vaild)) # 0.9940456584701005
# Out:
# 0.9940513373842921

# %%
# RandomForestClassifier Predict
from sklearn.metrics import accuracy_score, f1_score

y_pred = rf.predict(scaled_test_x)

# %%
# RandomForestClassifier Score
print('rf_accuracy_score : {:.2f} %'.format(accuracy_score(labeled_test_y, y_pred)*100))
print('rf_f1_socre : {:.2f} %'.format(f1_score(labeled_test_y, y_pred)*100))
# Out:
# rf_accuracy_score : 83.38 %
# rf_f1_socre : 85.66 %

# %%
# GBM Train
from sklearn.ensemble import GradientBoostingClassifier

gbm = GradientBoostingClassifier()  # random_state = ?
gbm.fit(X_train, y_train)   # 학습시간이 RandomForest에 비해 오래걸림, 보통 예측 성능이 더 뛰어나지만 시간이 느린 것이 단점으로 꼽힘

print(gbm.score(X_vaild, y_vaild)) #0.9963796922028508
# Out:
# 0.9963796922028508

# %%
# GBM Predict
y_pred = gbm.predict(scaled_test_x)

# %%
# GBM Score
print('gbm_accuracy_score : {:.2f} %'.format(accuracy_score(labeled_test_y, y_pred)*100))
print('gbm_f1_socre : {:.2f} %'.format(f1_score(labeled_test_y, y_pred)*100))
# Out:
# gbm_accuracy_score : 80.93 %
# gbm_f1_socre : 83.19 %

# %% [markdown]
# ## 4. Hyperparameters Tuning

# %% [markdown]
# # 5. Model Save

# %%
# Save Model
import joblib
joblib.dump(rf, './models/RandomForestClassifier.pkl')
joblib.dump(gbm, './models/GradientBoostingClassifier.pkl')
# Out:
# ['./models/GradientBoostingClassifier.pkl']

# %%
# Load Model
rf_load = joblib.load('./models/RandomForestClassifier.pkl')
rf_pred = rf_load.predict(scaled_test_x)
gbm_load = joblib.load('./models/GradientBoostingClassifier.pkl')
gbm_pred = gbm_load.predict(scaled_test_x)

print('loadRF_accuracy_score : {:.2f} %'.format(accuracy_score(labeled_test_y, rf_pred)*100))
print('loadRF_f1_socre : {:.2f} %'.format(f1_score(labeled_test_y, rf_pred)*100))
print('-'*40)
print('loadGBM_accuracy_score : {:.2f} %'.format(accuracy_score(labeled_test_y, gbm_pred)*100))
print('loadGBM_f1_socre : {:.2f} %'.format(f1_score(labeled_test_y, gbm_pred)*100))
# Out:
# loadRF_accuracy_score : 94.00 %
# loadRF_f1_socre : 95.26 %
# ----------------------------------------
# loadGBM_accuracy_score : 80.93 %
# loadGBM_f1_socre : 83.19 %

# %% [markdown]
# # 6. etc

# %%
# 라벨데이터 편향성 확인
labeled_test_y.value_counts()
# Out:
# 1    194501
# 0     98983
# Name: loginfo, dtype: int64
